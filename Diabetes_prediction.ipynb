# %% [markdown]
# **NAME : SAYED SARA SHAUKAT HUSSAIN**

# %% [markdown]
# **MACHINE LEARNING INTERNSHIP @ TECHNOHACKS**

# %% [markdown]
# **TASK 2**

# %% [markdown]
# # **PROJECT NAME - Diabetes Prediction System**

# %% [markdown]
# ## **Problem Statement**

# %% [markdown]
# Given a dataset of patient health records, the goal is to build a machine learning model that can accurately predict whether a patient is likely to develop diabetes.

# %% [markdown]
# **INPUTS**
#
# *   Medical History
# *   Demographic Information
#
# *   Lifestyle Factors
# *  Biochemical Measurements

# %% [markdown]
# **OUTPUT**
#
#
# * **Diabetes Prediction:**
#  The system will output a binary result indicating whether the patient is likely to develop diabetes (Yes/No).

# %% [markdown]
# Importing the Dependencies

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Data Collection and Analysis

# %%
# loading the diabetes dataset to a pandas DataFrame
diabetes = pd.read_csv('diabetes.csv')

# %%
# printing the first 5 rows of the dataset
diabetes.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# printing the first 5 rows of the dataset
diabetes.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
# number of rows and Columns in this dataset
diabetes.shape
# Out:
# (768, 9)

# %%
# getting the statistical measures of the data
diabetes.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
diabetes['Outcome'].value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %% [markdown]
# 0 --> Non-Diabetic
#
# 1 --> Diabetic

# %%
diabetes.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.298000  109.980000      68.184000      19.664000   68.792000
# 1           4.865672  141.257463      70.824627      22.164179  100.335821
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.304200                  0.429734  31.190000
# 1        35.142537                  0.550500  37.067164

# %%
# separating the data and labels
X = diabetes.drop(columns = 'Outcome', axis=1)
Y = diabetes['Outcome']

# %%
print(X)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %%
print(Y)
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %% [markdown]
# Data Standardization

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X)
# Out:
# StandardScaler()

# %%
standardized_data = scaler.transform(X)
print(standardized_data)
# Out:
# [[ 0.63994726  0.84832379  0.14964075 ...  0.20401277  0.46849198
#    1.4259954 ]
#  [-0.84488505 -1.12339636 -0.16054575 ... -0.68442195 -0.36506078
#   -0.19067191]
#  [ 1.23388019  1.94372388 -0.26394125 ... -1.10325546  0.60439732
#   -0.10558415]
#  ...
#  [ 0.3429808   0.00330087  0.14964075 ... -0.73518964 -0.68519336
#   -0.27575966]
#  [-0.84488505  0.1597866  -0.47073225 ... -0.24020459 -0.37110101
#    1.17073215]
#  [-0.84488505 -0.8730192   0.04624525 ... -0.20212881 -0.47378505
#   -0.87137393]]

# %%
X = standardized_data
Y = diabetes['Outcome']

# %%
print(X)
print(Y)
# Out:
# [[ 0.63994726  0.84832379  0.14964075 ...  0.20401277  0.46849198
#    1.4259954 ]
#  [-0.84488505 -1.12339636 -0.16054575 ... -0.68442195 -0.36506078
#   -0.19067191]
#  [ 1.23388019  1.94372388 -0.26394125 ... -1.10325546  0.60439732
#   -0.10558415]
#  ...
#  [ 0.3429808   0.00330087  0.14964075 ... -0.73518964 -0.68519336
#   -0.27575966]
#  [-0.84488505  0.1597866  -0.47073225 ... -0.24020459 -0.37110101
#    1.17073215]
#  [-0.84488505 -0.8730192   0.04624525 ... -0.20212881 -0.47378505
#   -0.87137393]]
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %% [markdown]
# Train Test Split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size = 0.2, stratify=Y, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (768, 8) (614, 8) (154, 8)

# %% [markdown]
# ## **Training the Model using Support Vector Machine(SVM)**

# %%
from sklearn import svm
model_svc = svm.SVC(kernel='linear', C=1)

# %%
#training the support vector Machine Classifier
model_svc.fit(X_train, Y_train)
# Out:
# SVC(C=1, kernel='linear')

# %% [markdown]
# Model Evaluation :
# Accuracy Score

# %%
from sklearn.metrics import accuracy_score

# accuracy score on the training data
X_train_prediction = model_svc.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print('Accuracy score of the training data : ', training_data_accuracy)
# Out:
# Accuracy score of the training data :  0.7866449511400652

# %%
# accuracy score on the test data
X_test_prediction = model_svc.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print('Accuracy score of the test data : ', test_data_accuracy)
# Out:
# Accuracy score of the test data :  0.7727272727272727

# %% [markdown]
# Making a Predictive System

# %% [markdown]
# Input data diabetic

# %%
from sklearn.preprocessing import StandardScaler

# Remove missing values and duplicates
data = diabetes.dropna().drop_duplicates()

# Define features and target
X = data.drop('Outcome', axis=1)
Y = data['Outcome']

# Split the data into training and testing sets with stratification
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

# Initialize the standard scaler
scaler = StandardScaler()

# Fit and transform the training data
X_train = scaler.fit_transform(X_train)

# Transform the testing data
X_test = scaler.transform(X_test)

# Initialize and train the SVM model
model_svc = svm.SVC(kernel='linear', C=1)
model_svc.fit(X_train, Y_train)

# Evaluate the model
Y_pred = model_svc.predict(X_test)


input_data = (5,166,72,19,175,25.8,0.587,51)

# changing the input_data to numpy array
input_data_as_numpy_array = np.asarray(input_data)

# reshape the array as we are predicting for one instance
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

# standardize the input data
std_data = scaler.transform(input_data_reshaped)
print(std_data)

prediction = model_svc.predict(std_data)
print("prediction:", prediction)

if (prediction[0] == 0):
  print('The person is not diabetic')
else:
  print('The person is diabetic')
# Out:
# [[ 0.344238    1.40148656  0.12781322 -0.10834817  0.77530224 -0.79714106
#    0.34797285  1.51129009]]
# prediction: [1]
# The person is diabetic
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %% [markdown]
# Input data not diabetic

# %%
# Input data likely to predict the person is not diabetic
input_data_not_diabetic = (1, 100, 70, 15, 50, 20.0, 0.300, 25)  # (Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age)

# Convert the input data to a numpy array and reshape it
input_data_as_numpy_array = np.asarray(input_data_not_diabetic).reshape(1, -1)

# Standardize the input data
std_input_data = scaler.transform(input_data_as_numpy_array)

# Predict using the SVM model
prediction = model_svc.predict(std_input_data)
print("Prediction using SVM:")

# Make a prediction
prediction = model_svc.predict(std_input_data)
print("Prediction:", prediction)

if prediction[0] == 0:
    print('The person is not diabetic')
else:
    print('The person is diabetic')
# Out:
# Prediction using SVM:
# Prediction: [0]
# The person is not diabetic
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ## **Training the model using Logistic Regression**

# %% [markdown]
# Model Evaluation : Accuracy Score

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# Initialize and train the Logistic Regression model
model_lr = LogisticRegression(max_iter=1000)
model_lr.fit(X_train, Y_train)

# Make predictions on the test set
Y_pred = model_lr.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(Y_test, Y_pred)

print(f'Accuracy: {accuracy}')
# Out:
# Accuracy: 0.7597402597402597

# %% [markdown]
# Making a predictive system

# %% [markdown]
# Input data diabetic

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler

# Check for missing values and remove them if necessary
data = data.dropna()

# Check for duplicate rows and remove them if necessary
data = data.drop_duplicates()

# Define feature columns and target column
X = data.drop('Outcome', axis=1)  # 'Outcome' is the target column
Y = data['Outcome']

# Split the data into training and testing sets with stratification
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

# Initialize the standard scaler
scaler = StandardScaler()

# Fit and transform the training data
X_train = scaler.fit_transform(X_train)

# Transform the testing data
X_test = scaler.transform(X_test)

# Initialize and train the Logistic Regression model
model_lr = LogisticRegression(max_iter=1000)
model_lr.fit(X_train, Y_train)

# Make predictions on the test set
Y_pred = model_lr.predict(X_test)

# Predict whether a person is diabetic based on input data
input_data = (5, 166, 72, 19, 175, 25.8, 0.587, 51)

# Convert the input data to a numpy array
input_data_as_numpy_array = np.asarray(input_data)

# Reshape the array as we are predicting for one instance
input_data_reshaped = input_data_as_numpy_array.reshape(1, -1)

# Standardize the input data
std_data = scaler.transform(input_data_reshaped)
print("Standardized input data:", std_data)

# Make a prediction
prediction = model_lr.predict(std_data)
print("Prediction:", prediction)

if prediction[0] == 0:
    print('The person is not diabetic')
else:
    print('The person is diabetic')
# Out:
# Standardized input data: [[ 0.344238    1.40148656  0.12781322 -0.10834817  0.77530224 -0.79714106
#    0.34797285  1.51129009]]
# Prediction: [1]
# The person is diabetic
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %% [markdown]
# Input data not diabetic

# %%
# Input data likely to predict the person is not diabetic
input_data_not_diabetic = (1, 100, 70, 15, 50, 20.0, 0.300, 25)  # (Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age)

# Convert the input data to a numpy array and reshape it
input_data_as_numpy_array = np.asarray(input_data_not_diabetic).reshape(1, -1)

# Standardize the input data
std_input_data = scaler.transform(input_data_as_numpy_array)

# Predict using the SVM model
prediction = model_lr.predict(std_input_data)
print("Prediction using Logistic Regression:")

# Make a prediction
prediction = model_lr.predict(std_input_data)
print("Prediction:", prediction)

if prediction[0] == 0:
    print('The person is not diabetic')
else:
    print('The person is diabetic')
# Out:
# Prediction using Logistic Regression:
# Prediction: [0]
# The person is not diabetic
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ## **Training the model using Decision Tree Classifier**

# %% [markdown]
# Model Evaluation : Accuracy Score

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# Initialize the Decision Tree model
model_dt = DecisionTreeClassifier(random_state=2)

# Train the model on the training data
model_dt.fit(X_train, Y_train)

# Make predictions on the test data
Y_pred_dt = model_dt.predict(X_test)

# Evaluate the model
accuracy_dt = accuracy_score(Y_test, Y_pred_dt)
print(f'Accuracy: {accuracy_dt}')
# Out:
# Accuracy: 0.7012987012987013

# %% [markdown]
# Making a predictive system

# %% [markdown]
# Input data diabetic

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import StandardScaler

# Check for missing values and remove them if necessary
data = data.dropna()

# Check for duplicate rows and remove them if necessary
data = data.drop_duplicates()

# Define feature columns and target column
X = data.drop('Outcome', axis=1)  # 'Outcome' is the target column
Y = data['Outcome']

# Split the data into training and testing sets with stratification
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

# Initialize the standard scaler
scaler = StandardScaler()

# Fit and transform the training data
X_train = scaler.fit_transform(X_train)

# Transform the testing data
X_test = scaler.transform(X_test)

# Initialize and train the Logistic Regression model
model_dt = LogisticRegression(max_iter=1000)
model_dt.fit(X_train, Y_train)

# Make predictions on the test set
Y_pred = model_dt.predict(X_test)

# New input data
input_data = (5, 166, 72, 19, 175, 25.8, 0.587, 51)

# Convert the input data to a numpy array and reshape it
input_data_as_numpy_array = np.asarray(input_data).reshape(1, -1)

# Standardize the input data
std_input_data = scaler.transform(input_data_as_numpy_array)

# Predict using the Decision Tree model
prediction_dt = model_dt.predict(std_input_data)
print("Prediction using Decision Tree:")

# Make a prediction
prediction = model_dt.predict(std_data)
print("Prediction:", prediction)

if prediction_dt[0] == 0:
    print('The person is not diabetic')
else:
    print('The person is diabetic')
# Out:
# Prediction using Decision Tree:
# Prediction: [1]
# The person is diabetic
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %% [markdown]
# Input data not diabetic

# %%
# Input data likely to predict the person is not diabetic
input_data_not_diabetic = (1, 100, 70, 15, 50, 20.0, 0.300, 25)  # (Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age)

# Convert the input data to a numpy array and reshape it
input_data_as_numpy_array = np.asarray(input_data_not_diabetic).reshape(1, -1)

# Standardize the input data
std_input_data = scaler.transform(input_data_as_numpy_array)

# Predict using the SVM model
prediction = model_dt.predict(std_input_data)
print("Prediction using Decision Tree:")

# Make a prediction
prediction = model_dt.predict(std_input_data)
print("Prediction:", prediction)

if prediction[0] == 0:
    print('The person is not diabetic')
else:
    print('The person is diabetic')
# Out:
# Prediction using Decision Tree:
# Prediction: [0]
# The person is not diabetic
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
